#        2013-03-06 -0.009132  0.532290     0.589036
#        2013-03-07  0.009217  0.541507     0.590822
#        2013-03-08  0.004566  0.546073     0.595112
#        2013-03-11  0.000000  0.546073     0.598908
#        2013-03-12  0.004545  0.550618     0.596665
#        2013-03-13  0.000000  0.550618     0.598110
#        2013-03-14  0.000000  0.550618     0.603402
#        2013-03-15 -0.009050  0.541568     0.602086
#        2013-03-18  0.000000  0.541568     0.596567
#
# [33563055 rows x 3 columns]

# %%
spy = crsp_prices.reset_index().set_index('date')['spy_cum_ret']
spy
# Out:
# date
# 2000-01-03   -0.009787
# 2000-01-04   -0.048893
# 2000-01-05   -0.047104
# 2000-01-06   -0.063175
# 2000-01-07   -0.005099
# 2000-01-10   -0.001668
# 2000-01-11   -0.014916
# 2000-01-12   -0.023578
# 2000-01-13   -0.010035
# 2000-01-14    0.003543
# 2000-01-18   -0.004324
# 2000-01-19   -0.001324
# 2000-01-20   -0.011580
# 2000-01-21   -0.013739
# 2000-01-24   -0.042082
# 2000-01-25   -0.030726
# 2000-01-26   -0.038652
# 2000-01-27   -0.042647
# 2000-01-28   -0.073841
# 2000-01-31   -0.046242
# 2000-02-01   -0.036842
# 2000-02-02   -0.035955
# 2000-02-03   -0.020891
# 2000-02-04   -0.025038
# 2000-02-07   -0.026572
# 2000-02-08   -0.012964
# 2000-02-09   -0.033969
# 2000-02-10   -0.031978
# 2000-02-11   -0.052287
# 2000-02-14   -0.046429
#                 ...
# 2013-02-04    0.555782
# 2013-02-05    0.565913
# 2013-02-06    0.566641
# 2013-02-07    0.565318
# 2013-02-08    0.570882
# 2013-02-11    0.570684
# 2013-02-12    0.572331
# 2013-02-13    0.573193
# 2013-02-14    0.574107
# 2013-02-15    0.572925
# 2013-02-19    0.580420
# 2013-02-20    0.567957
# 2013-02-21    0.561878
# 2013-02-22    0.571651
# 2013-02-25    0.552624
# 2013-02-26    0.559470
# 2013-02-27    0.572068
# 2013-02-28    0.570093
# 2013-03-01    0.573391
# 2013-03-04    0.578716
# 2013-03-05    0.587675
# 2013-03-06    0.589036
# 2013-03-07    0.590822
# 2013-03-08    0.595112
# 2013-03-11    0.598908
# 2013-03-12    0.596665
# 2013-03-13    0.598110
# 2013-03-14    0.603402
# 2013-03-15    0.602086
# 2013-03-18    0.596567
# Name: spy_cum_ret, Length: 33563055, dtype: float64

# %%
crsp_prices.head(10)
# Out:
#                      return   cum_ret  spy_cum_ret
# ticker date
# A      2000-01-03 -0.068715 -0.068715    -0.009787
#        2000-01-04 -0.089410 -0.158125    -0.048893
#        2000-01-05 -0.048618 -0.206743    -0.047104
#        2000-01-06 -0.054108 -0.260851    -0.063175
#        2000-01-07  0.101695 -0.159156    -0.005099
#        2000-01-10  0.060577 -0.098579    -0.001668
#        2000-01-11 -0.013599 -0.112178    -0.014916
#        2000-01-12 -0.020221 -0.132399    -0.023578
#        2000-01-13  0.015009 -0.117390    -0.010035
#        2000-01-14  0.011091 -0.106299     0.003543

# %%
crsp_prices = crsp_prices.swaplevel()

# %%
crsp_prices.sort_index(inplace=True)

# %%
crsp_prices.head()
# Out:
#                      return   cum_ret  spy_cum_ret
# date       ticker
# 2000-01-03 A      -0.068715 -0.068715    -0.009787
#            AA     -0.024849 -0.024849    -0.009787
#            AAABB  -0.007353 -0.007353    -0.009787
#            AABC   -0.015748 -0.015748    -0.009787
#            AAC     0.028169  0.028169    -0.009787

# %%
crsp_prices = crsp_prices[~crsp_prices.index.duplicated()]

# %%
ratios = pd.read_pickle(r'C:\Users\niels\data\Quarterly-Ratios.pkl')

# %%
ratios.rename(columns={'rdq':'date','tic':'ticker'},inplace=True)

# %%
ratios.set_index(['date'],inplace=True)

# %%
from pandas.tseries.offsets import BDay
ratios.index = ratios.index.map(lambda x : x + BDay())

# %%
ratios.reset_index(inplace=True)

# %%
ratios.set_index(['date','ticker'],inplace=True)

# %%
ratios.sort_index(inplace=True)

# %%
ratios = ratios.loc[ratios.index.get_level_values(1).notnull()]

# %%
ratios = ratios[ratios['curcdq']=='USD']

# %%
merged = ratios.merge(crsp_prices,left_index=True,right_index=True)

# %%
merged.reset_index(inplace=True)

# %%
merged.set_index('date',inplace=True)

# %%
merged['next_period_return'] = \
merged.groupby('ticker')['cum_ret'].transform(pd.Series.diff)

# %%
merged['spy_next_period_return'] = \
merged.groupby('ticker')['spy_cum_ret'].transform(pd.Series.diff)

# %%
merged['next_period_return'] = merged.groupby('ticker')['next_period_return'].shift(-1)

# %%
merged['spy_next_period_return'] = merged.groupby('ticker')['spy_next_period_return'].shift(-1)

# %%
merged.reset_index(inplace=True)

# %%
merged.set_index(['date','ticker'],inplace=True)

# %%
merged.sort_index(inplace=True)

# %%
merged.drop(['gvkey',
             'fyr',
             'fyearq',
             'level_0',
             'index',
             'indfmt',
             'consol',
             'datafmt',
             'popsrc',
             'costat',
             'ipodate',
             'datadate',
             'curcdq',
             'datacqtr',
             'datafqtr',
             'ajexq'
            ],axis=1,inplace=True)

# %%
merged['cshopq'].fillna(0.0,inplace=True)

# %%
merged['pred_rel_return'] = merged['next_period_return'] - merged['spy_next_period_return']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

merged.loc[(slice(None),'AAPL'),:]['pred_rel_return'].plot();

# %%
merged = pd.get_dummies(merged,prefix='fqtr',columns=['fqtr'])

# %%
merged = pd.get_dummies(merged,prefix='sic',columns=['sic'])

# %%
merged = pd.get_dummies(merged,columns=['spcsrc'])

# %%
merged = pd.get_dummies(merged,prefix='sector_code',columns=['spcindcd'])

# %%
merged.to_csv(r'C:\Users\niels\data\dataset.csv')

# %%
merged.to_pickle(r'C:\Users\niels\data\dataset.pkl')
