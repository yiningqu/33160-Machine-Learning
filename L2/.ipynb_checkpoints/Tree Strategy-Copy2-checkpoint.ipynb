# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import accuracy_score, confusion_matrix
# avoid infinity value
pd.set_option('use_inf_as_na', True)
from collections import Counter

# %% [markdown]
# ## Loading the Data Set (you need to put in the file where you have stored the data)

# %%
raw_data = pd.read_pickle(r'C:\Users\niels\OneDrive\Machine Learning 2022\Lecture 2\dataset.pkl')

# %%
raw_data.head()
# Out:
#                        actq      apq        atq       ceqq      cheq  \
# date       ticker
# 2000-02-01 LLB        3.540    0.143      7.668      6.732     2.553
# 2000-02-03 MYR      107.661   24.387    220.463    136.555     1.049
# 2000-02-08 LZB      447.719   57.893    740.905    460.612    16.531
#            SJM      234.415   33.821    488.136    322.432    26.054
# 2000-02-09 CSCO    7722.000  482.000  21391.000  16523.000  3968.000
#
#                       cogsq     csh12q    cshfdq     cshiq  cshopq  ...  \
# date       ticker                                                   ...
# 2000-02-01 LLB        0.458     6.3910     6.391     6.989     0.0  ...
# 2000-02-03 MYR       36.883    25.5360    22.082    28.458     0.0  ...
# 2000-02-08 LZB      274.525    52.2660    52.274    52.544     0.0  ...
#            SJM       91.172    28.8808    28.603    32.425     0.0  ...
# 2000-02-09 CSCO    1422.000  3374.1250  3648.000  3445.000     0.0  ...
#
#                    sector_code_815.0  sector_code_817.0  sector_code_822.0  \
# date       ticker
# 2000-02-01 LLB                     0                  0                  0
# 2000-02-03 MYR                     0                  0                  0
# 2000-02-08 LZB                     0                  0                  0
#            SJM                     0                  0                  0
# 2000-02-09 CSCO                    0                  0                  0
#
#                    sector_code_823.0  sector_code_825.0  sector_code_830.0  \
# date       ticker
# 2000-02-01 LLB                     0                  0                  0
# 2000-02-03 MYR                     0                  0                  0
# 2000-02-08 LZB                     0                  0                  0
#            SJM                     0                  0                  0
# 2000-02-09 CSCO                    0                  0                  0
#
#                    sector_code_835.0  sector_code_840.0  sector_code_845.0  \
# date       ticker
# 2000-02-01 LLB                     0                  0                  0
# 2000-02-03 MYR                     0                  0                  0
# 2000-02-08 LZB                     0                  0                  0
#            SJM                     0                  0                  0
# 2000-02-09 CSCO                    0                  0                  0
#
#                    sector_code_850.0
# date       ticker
# 2000-02-01 LLB                     0
# 2000-02-03 MYR                     0
# 2000-02-08 LZB                     0
#            SJM                     0
# 2000-02-09 CSCO                    0
#
# [5 rows x 731 columns]

# %%
raw_data = raw_data.drop([x  for x in raw_data.columns if 'fqtr' in x],axis=1)

# %% [markdown]
# ## Restricting to Companies with Market Cap > 1 Billion

# %%
data = raw_data[raw_data['market_cap'] > 1000.0]

# %% [markdown]
# ## The Total Number of Companies w/ Market Cap > 1 Billion that appear during our time horizon

# %%
len(data.index.get_level_values(1).unique())
# Out:
# 4076

# %%
data.head()
# Out:
#                        actq       apq        atq       ceqq      cheq  \
# date       ticker
# 2000-02-09 CSCO    7722.000   482.000  21391.000  16523.000  3968.000
#            ROP      172.725    19.662    474.649    239.432     3.198
# 2000-02-10 CMOS     240.767    27.044    376.536    209.411    68.625
# 2000-02-11 DELL    7681.000  3538.000  11471.000   5308.000  4132.000
# 2000-02-15 VAL      507.082   139.497   1094.080    402.382    27.605
#
#                       cogsq     csh12q    cshfdq     cshiq  cshopq  ...  \
# date       ticker                                                   ...
# 2000-02-09 CSCO    1422.000  3374.1250  3648.000  3445.000     0.0  ...
#            ROP       47.634    30.2688    31.217       NaN     0.0  ...
# 2000-02-10 CMOS      43.023    21.4360    23.753       NaN     0.0  ...
# 2000-02-11 DELL    5452.000  2536.0000  2731.000  2575.000     0.0  ...
# 2000-02-15 VAL      221.366    43.1858    43.687    53.321     0.0  ...
#
#                    sector_code_815.0  sector_code_817.0  sector_code_822.0  \
# date       ticker
# 2000-02-09 CSCO                    0                  0                  0
#            ROP                     0                  0                  0
# 2000-02-10 CMOS                    0                  0                  0
# 2000-02-11 DELL                    0                  0                  0
# 2000-02-15 VAL                     0                  0                  0
#
#                    sector_code_823.0  sector_code_825.0  sector_code_830.0  \
# date       ticker
# 2000-02-09 CSCO                    0                  0                  0
#            ROP                     0                  0                  0
# 2000-02-10 CMOS                    0                  0                  0
# 2000-02-11 DELL                    0                  0                  0
# 2000-02-15 VAL                     0                  0                  0
#
#                    sector_code_835.0  sector_code_840.0  sector_code_845.0  \
# date       ticker
# 2000-02-09 CSCO                    0                  0                  0
#            ROP                     0                  0                  0
# 2000-02-10 CMOS                    0                  0                  0
# 2000-02-11 DELL                    0                  0                  0
# 2000-02-15 VAL                     0                  0                  0
#
#                    sector_code_850.0
# date       ticker
# 2000-02-09 CSCO                    0
#            ROP                     0
# 2000-02-10 CMOS                    0
# 2000-02-11 DELL                    0
# 2000-02-15 VAL                     0
#
# [5 rows x 727 columns]

# %% [markdown]
# ## Filling in Missing Values

# %%
data = data.copy()
data.replace([np.inf,-np.inf],np.nan,inplace=True)
data = data.fillna(method='ffill')

# %%
data = data.fillna(0)

# %%
data['pred_rel_return']
# Out:
# date        ticker
# 2000-02-09  CSCO     -0.025923
#             ROP       0.066175
# 2000-02-10  CMOS      0.241345
# 2000-02-11  DELL      0.306035
# 2000-02-15  VAL       0.043852
#                         ...
# 2018-12-21  NKE      -0.100100
#             SAFM     -0.100100
#             SCHL     -0.100100
#             WBA      -0.100100
# 2018-12-24  KMX      -0.100100
# Name: pred_rel_return, Length: 111468, dtype: float64

# %% [markdown]
# #### We label a Data Point +1 if the difference between the return on the SPY and the return on the stock exceeds 1.0% during the earnings period, -1 if it is < -2.5% and 0 if it is between -2.5% and +1%. The function below turns the return differences into labels

# %%
def f(x):
    if x > 0.01:
        return 1
    elif x < -0.025:
        return -1
    else:
        return 0

# %% [markdown]
# #### Applying the function to the column of relative returns and making a column of labels

# %%
data = data.copy()
data['rel_performance'] = data['pred_rel_return'].apply(f)

# %%
data['next_period_return'].to_frame()
# Out:
#                    next_period_return
# date       ticker
# 2000-02-09 CSCO             -0.037098
#            ROP               0.077255
# 2000-02-10 CMOS              0.287974
# 2000-02-11 DELL              0.346867
# 2000-02-15 VAL               0.093507
# ...                               ...
# 2018-12-21 NKE              -0.207949
#            SAFM             -0.207949
#            SCHL             -0.207949
#            WBA              -0.207949
# 2018-12-24 KMX              -0.207949
#
# [111468 rows x 1 columns]

# %% [markdown]
# #### This is the column of labels

# %%
data['rel_performance']
# Out:
# date        ticker
# 2000-02-09  CSCO     -1
#             ROP       1
# 2000-02-10  CMOS      1
# 2000-02-11  DELL      1
# 2000-02-15  VAL       1
#                      ..
# 2018-12-21  NKE      -1
#             SAFM     -1
#             SCHL     -1
#             WBA      -1
# 2018-12-24  KMX      -1
# Name: rel_performance, Length: 111468, dtype: int64

# %% [markdown]
# ### Make date the index, remember that the date is the first business day after Earnings Release

# %%
data.reset_index(inplace=True)
data.set_index('date',inplace=True)

# %%
data.head()
# Out:
#            ticker      actq       apq        atq       ceqq      cheq  \
# date
# 2000-02-09   CSCO  7722.000   482.000  21391.000  16523.000  3968.000
# 2000-02-09    ROP   172.725    19.662    474.649    239.432     3.198
# 2000-02-10   CMOS   240.767    27.044    376.536    209.411    68.625
# 2000-02-11   DELL  7681.000  3538.000  11471.000   5308.000  4132.000
# 2000-02-15    VAL   507.082   139.497   1094.080    402.382    27.605
#
#                cogsq     csh12q    cshfdq     cshiq  ...  sector_code_817.0  \
# date                                                 ...
# 2000-02-09  1422.000  3374.1250  3648.000  3445.000  ...                  0
# 2000-02-09    47.634    30.2688    31.217  3445.000  ...                  0
# 2000-02-10    43.023    21.4360    23.753  3445.000  ...                  0
# 2000-02-11  5452.000  2536.0000  2731.000  2575.000  ...                  0
# 2000-02-15   221.366    43.1858    43.687    53.321  ...                  0
#
#             sector_code_822.0  sector_code_823.0  sector_code_825.0  \
# date
# 2000-02-09                  0                  0                  0
# 2000-02-09                  0                  0                  0
# 2000-02-10                  0                  0                  0
# 2000-02-11                  0                  0                  0
# 2000-02-15                  0                  0                  0
#
#             sector_code_830.0  sector_code_835.0  sector_code_840.0  \
# date
# 2000-02-09                  0                  0                  0
# 2000-02-09                  0                  0                  0
# 2000-02-10                  0                  0                  0
# 2000-02-11                  0                  0                  0
# 2000-02-15                  0                  0                  0
#
#             sector_code_845.0  sector_code_850.0  rel_performance
# date
# 2000-02-09                  0                  0               -1
# 2000-02-09                  0                  0                1
# 2000-02-10                  0                  0                1
# 2000-02-11                  0                  0                1
# 2000-02-15                  0                  0                1
#
# [5 rows x 729 columns]

# %% [markdown]
# ### This what the data set looks like now

# %%
data
# Out:
#            ticker       actq        apq        atq       ceqq      cheq  \
# date
# 2000-02-09   CSCO   7722.000    482.000  21391.000  16523.000  3968.000
# 2000-02-09    ROP    172.725     19.662    474.649    239.432     3.198
# 2000-02-10   CMOS    240.767     27.044    376.536    209.411    68.625
# 2000-02-11   DELL   7681.000   3538.000  11471.000   5308.000  4132.000
# 2000-02-15    VAL    507.082    139.497   1094.080    402.382    27.605
# ...           ...        ...        ...        ...        ...       ...
# 2018-12-21    NKE  15566.000   2574.000  22677.000   8729.000  4041.000
# 2018-12-21   SAFM    566.489    128.936   1659.440   1387.893   121.193
# 2018-12-21   SCHL   1172.300    250.300   2081.900   1284.600   358.100
# 2018-12-21    WBA  20083.000  14660.000  69941.000  25609.000  1183.000
# 2018-12-24    KMX   3057.419    558.324  18396.812   3435.113   461.662
#
#                 cogsq     csh12q    cshfdq     cshiq  ...  sector_code_817.0  \
# date                                                  ...
# 2000-02-09   1422.000  3374.1250  3648.000  3445.000  ...                  0
# 2000-02-09     47.634    30.2688    31.217  3445.000  ...                  0
# 2000-02-10     43.023    21.4360    23.753  3445.000  ...                  0
# 2000-02-11   5452.000  2536.0000  2731.000  2575.000  ...                  0
# 2000-02-15    221.366    43.1858    43.687    53.321  ...                  0
# ...               ...        ...       ...       ...  ...                ...
# 2018-12-21   5098.000  1601.1500  1620.700  1577.000  ...                  0
# 2018-12-21    758.313    22.4290    22.191    22.100  ...                  0
# 2018-12-21    262.400    35.0420    35.863    22.100  ...                  0
# 2018-12-21  25651.000   976.4750   951.400  1172.514  ...                  0
# 2018-12-24   3819.336   177.2235   175.321   171.785  ...                  0
#
#             sector_code_822.0  sector_code_823.0  sector_code_825.0  \
# date
# 2000-02-09                  0                  0                  0
# 2000-02-09                  0                  0                  0
# 2000-02-10                  0                  0                  0
# 2000-02-11                  0                  0                  0
# 2000-02-15                  0                  0                  0
# ...                       ...                ...                ...
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-24                  0                  0                  0
#
#             sector_code_830.0  sector_code_835.0  sector_code_840.0  \
# date
# 2000-02-09                  0                  0                  0
# 2000-02-09                  0                  0                  0
# 2000-02-10                  0                  0                  0
# 2000-02-11                  0                  0                  0
# 2000-02-15                  0                  0                  0
# ...                       ...                ...                ...
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-21                  0                  0                  0
# 2018-12-24                  0                  0                  0
#
#             sector_code_845.0  sector_code_850.0  rel_performance
# date
# 2000-02-09                  0                  0               -1
# 2000-02-09                  0                  0                1
# 2000-02-10                  0                  0                1
# 2000-02-11                  0                  0                1
# 2000-02-15                  0                  0                1
# ...                       ...                ...              ...
# 2018-12-21                  0                  0               -1
# 2018-12-21                  0                  0               -1
# 2018-12-21                  0                  0               -1
# 2018-12-21                  0                  0               -1
# 2018-12-24                  0                  0               -1
#
# [111468 rows x 729 columns]

# %% [markdown]
# ### We use a training period of 3 years = 12 quarters,

# %%
df_train = data.loc['2001-01-01':'2004-01-01']

# %% [markdown]
# #### The validation set and test set are the quarters starting 1 quarter after the end of the training periods

# %%
df_valid = data.loc['2004-04-01':'2004-07-01']
df_test = data.loc['2004-10-01':'2005-01-01']

# %% [markdown]
# #### Next we delete the columns that are not needed for training

# %%
train = df_train.reset_index().drop(['ticker','date',
                                   'next_period_return',
                                   'spy_next_period_return',
                                   'rel_performance','pred_rel_return',
                                  'return', 'cum_ret', 'spy_cum_ret'],axis=1)

valid = df_valid.reset_index().drop(['ticker','date',
                                   'next_period_return',
                                   'spy_next_period_return',
                                   'rel_performance','pred_rel_return',
                                  'return', 'cum_ret', 'spy_cum_ret',
                                    ],axis=1)
test = df_test.reset_index().drop(['ticker','date',
                                   'next_period_return',
                                   'spy_next_period_return',
                                   'rel_performance','pred_rel_return',
                                  'return', 'cum_ret', 'spy_cum_ret',
                            ],axis=1)

# %% [markdown]
# #### We take out the actual  earnings period stock returns in the training and test sets

# %%
train_stock_returns = df_train['next_period_return']
valid_stock_returns = df_valid['next_period_return']
test_stock_returns = df_test['next_period_return']

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
scaler = StandardScaler()

# %%
float_vars = [x for x in train.columns if data[x].dtype == 'float64']

# %%
len(float_vars)
# Out:
# 179

# %%
float_vars
# Out:
# ['actq',
#  'apq',
#  'atq',
#  'ceqq',
#  'cheq',
#  'cogsq',
#  'csh12q',
#  'cshfdq',
#  'cshiq',
#  'cshopq',
#  'cshoq',
#  'cshprq',
#  'cstkq',
#  'dlcq',
#  'dlttq',
#  'dpq',
#  'dvpq',
#  'epsf12',
#  'epsfi12',
#  'epsfiq',
#  'epsfxq',
#  'epspi12',
#  'epspiq',
#  'epspxq',
#  'epsx12',
#  'ibadj12',
#  'ibadjq',
#  'ibcomq',
#  'ibq',
#  'icaptq',
#  'invtq',
#  'lctq',
#  'ltq',
#  'mibq',
#  'miiq',
#  'niq',
#  'nopiq',
#  'oepf12',
#  'oeps12',
#  'oepsxq',
#  'oiadpq',
#  'oibdpq',
#  'opepsq',
#  'optdrq',
#  'piq',
#  'ppentq',
#  'prcraq',
#  'pstkq',
#  'pstkrq',
#  'rectq',
#  'req',
#  'revtq',
#  'saleq',
#  'seqq',
#  'spiq',
#  'teqq',
#  'txdbq',
#  'txditcq',
#  'txpq',
#  'txtq',
#  'xintq',
#  'xoprq',
#  'xrdq',
#  'xsgaq',
#  'capxy',
#  'cdvcy',
#  'chechy',
#  'cogsy',
#  'dlcchy',
#  'dltisy',
#  'dltry',
#  'dpcy',
#  'dvy',
#  'ibcomy',
#  'ibcy',
#  'miiy',
#  'oancfy',
#  'oepsxy',
#  'oibdpy',
#  'revty',
#  'txpdy',
#  'xidocy',
#  'xidoy',
#  'xinty',
#  'xrdy',
#  'xsgay',
#  'dvpspq',
#  'prccq',
#  'beq',
#  'bmq',
#  'book_value_per_share',
#  'book_value_yield',
#  'market_cap',
#  'buy_back_yield',
#  'yearly_sales',
#  'evmq',
#  'pe_op_basicq',
#  'pe_op_dilq',
#  'pe_exiq',
#  'capeiq',
#  'pe_incq',
#  'psq',
#  'oancfy_q',
#  'opcfq',
#  'cfo-per-share',
#  'cf_yield',
#  'pcfq',
#  'dvq',
#  'dprq',
#  'npmq',
#  'opmbdq',
#  'opmadq',
#  'gpmq',
#  'ptpmq',
#  'ibcq',
#  'dpcq',
#  'cfmq',
#  'at4',
#  'roaq',
#  'roceq',
#  'efftaxq',
#  'ceq4',
#  'seq4',
#  'lctq4',
#  'be4',
#  'lagbe4',
#  'lagseq4',
#  'lagicapt4',
#  'lagppent4',
#  'lagppent_alt4',
#  'roeq',
#  'aftret_eqq',
#  'aftret_invcapxq',
#  'aftret_equityq',
#  'pretret_noaq',
#  'pretret_earnatq',
#  'gprofq',
#  'equity_invcapq',
#  'debt_invcapq',
#  'totdebt_invcapq',
#  'capital_ratioq',
#  'int_debtq',
#  'int_totdebtq',
#  'cash_ltq',
#  'invt_actq',
#  'rect_actq',
#  'debt_atq',
#  'debt_ebitdaq',
#  'short_debtq',
#  'curr_debtq',
#  'lt_debtq',
#  'profit_lctq',
#  'ocf_lctq',
#  'capxq',
#  'fcf_ocfq',
#  'fcf_csfhdq',
#  'fcf_yield',
#  'cash_debtq',
#  'lt_ppentq',
#  'dltt_beq',
#  'debt_assetsq',
#  'debt_capitalq',
#  'de_ratioq',
#  'intcovq',
#  'intcov_ratioq',
#  'cash_ratioq',
#  'quick_ratioq',
#  'curr_ratioq',
#  'cash_conversionq',
#  'inv_turnq',
#  'at_turnq',
#  'rect_turnq',
#  'pay_turnq',
#  'sale_invcapq',
#  'sale_equityq',
#  'sale_nwcq',
#  'rd_saleq',
#  'at5',
#  'accrualq']

# %%
train = train.copy()
valid = valid.copy()
test = test.copy()

# %%
train[float_vars] = scaler.fit_transform(train[float_vars])
valid[float_vars] = scaler.transform(valid[float_vars])
test[float_vars] = scaler.transform(test[float_vars])

# %%
test
# Out:
#           actq       apq       atq      ceqq      cheq     cogsq    csh12q  \
# 0    -0.263658 -0.161292 -0.237062 -0.198178 -0.075701 -0.301716 -0.199487
# 1     1.098392 -0.096349  0.239014  0.115424  0.008394 -0.007514  0.329885
# 2    -0.244494 -0.145633 -0.236138 -0.262953 -0.132820 -0.114253 -0.204665
# 3    -0.067779 -0.149890 -0.189368 -0.137015 -0.148266 -0.159950 -0.285349
# 4     0.996686  0.015795  0.096167  1.122966  0.065624  0.420599  1.717584
# ...        ...       ...       ...       ...       ...       ...       ...
# 1131  0.493980 -0.125321 -0.072877  0.162068 -0.121488  0.062230  0.233818
# 1132 -0.433373 -0.160534 -0.254654 -0.360778 -0.146589 -0.322603 -0.371124
# 1133  0.001727 -0.149717 -0.158878  0.272882 -0.066988 -0.204665  0.389613
# 1134 -0.447404 -0.162455 -0.262774 -0.398449 -0.144391 -0.319133 -0.389841
# 1135 -0.365539 -0.162725 -0.251698 -0.325265 -0.112106 -0.333306 -0.158593
#
#         cshfdq     cshiq       cshopq  ...  sector_code_815.0  \
# 0    -0.173131 -0.204266    -0.009609  ...                  0
# 1     0.333040  0.353212    -0.009609  ...                  0
# 2    -0.210057 -0.204298   164.468104  ...                  0
# 3    -0.275382 -0.296659     0.523026  ...                  0
# 4     1.743885  1.763815  1491.368621  ...                  0
# ...        ...       ...          ...  ...                ...
# 1131  0.227729  0.262613     7.660336  ...                  0
# 1132 -0.371085 -0.388166    -0.009609  ...                  0
# 1133  0.457127  0.320377    -0.009609  ...                  0
# 1134 -0.389502 -0.406740    -0.009609  ...                  0
# 1135 -0.140125 -0.171905     7.979917  ...                  0
#
#       sector_code_817.0  sector_code_822.0  sector_code_823.0  \
# 0                     0                  0                  0
# 1                     0                  0                  0
# 2                     0                  0                  0
# 3                     0                  0                  0
# 4                     0                  0                  0
# ...                 ...                ...                ...
# 1131                  0                  0                  0
# 1132                  0                  0                  0
# 1133                  0                  0                  0
# 1134                  0                  0                  0
# 1135                  0                  0                  0
#
#       sector_code_825.0  sector_code_830.0  sector_code_835.0  \
# 0                     0                  0                  0
# 1                     0                  0                  0
# 2                     0                  0                  0
# 3                     0                  0                  0
# 4                     0                  0                  0
# ...                 ...                ...                ...
# 1131                  0                  0                  0
# 1132                  0                  0                  0
# 1133                  0                  0                  0
# 1134                  0                  0                  0
# 1135                  0                  0                  0
#
#       sector_code_840.0  sector_code_845.0  sector_code_850.0
# 0                     0                  0                  0
# 1                     0                  0                  0
# 2                     0                  0                  0
# 3                     0                  0                  0
# 4                     0                  0                  0
# ...                 ...                ...                ...
# 1131                  0                  0                  0
# 1132                  0                  0                  0
# 1133                  0                  0                  0
# 1134                  0                  0                  0
# 1135                  0                  0                  0
#
# [1136 rows x 721 columns]

# %%
y_train = df_train['rel_performance'].values
y_valid = df_valid['rel_performance'].values
y_test = df_test['rel_performance'].values

# %%
y_train
# Out:
# array([ 1,  1,  1, ...,  1,  1, -1], dtype=int64)

# %%
Counter(y_valid)
# Out:
# Counter({1: 631, -1: 403, 0: 121})

# %% [markdown]
# ## Number of Features

# %%
len(train.columns)
# Out:
# 721

# %% [markdown]
# ## Importing the Tree Classifier and some metrics from sklearn

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
t_clf = DecisionTreeClassifier(min_samples_leaf = 100,max_depth=15)

# %%
t_clf.fit(train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=15, min_samples_leaf=100)

# %%
accuracy_score(y_train,t_clf.predict(train))
# Out:
# 0.6111162404210138

# %%
accuracy_score(y_valid,t_clf.predict(valid))
# Out:
# 0.5099567099567099

# %% [markdown]
# ### Visualizing the tree

# %%
import graphviz
from sklearn import tree

# %%
dot_data = tree.export_graphviz(t_clf,out_file=None)
graph = graphviz.Source(dot_data)
graph.render('tree_10')
# Out:
# 'tree_10.pdf'

# %%
# !pip install optuna

# %%
import optuna
from optuna.trial import Trial
# optuna.logging.set_verbosity(optuna.logging.get_verbosity)
# import warnings
# warnings.filterwarnings("ignore")

# %%
def objective(trial:Trial,train=None,labels=None,val=None,val_labels=None,val_rets=None):

    t_min_samples_leaf = trial.suggest_int('min_samples_leaf',100,1200,step=100)
    t_max_depth = trial.suggest_int('max_depth',5,25,step=5)

    
    t_clf = DecisionTreeClassifier(min_samples_leaf = t_min_samples_leaf,max_depth=t_max_depth,random_state=123)
    t_clf.fit(train,labels)

    preds = t_clf.predict(val)
    profit = (preds * val_rets).sum()

    return profit

# %%
study = optuna.create_study(direction="maximize")
# Out:
# [I 2023-01-28 11:51:26,705] A new study created in memory with name: no-name-3e48db2b-e0f4-4847-ad06-7a3236bb70b8

# %%
from functools import partial

# %%
# %%time
study.optimize(partial(objective,train=train,labels=y_train,val=valid,val_labels=y_valid,val_rets=valid_stock_returns.values), n_trials=100,n_jobs=-1)
# Out:
# [I 2023-01-28 11:51:32,494] Trial 0 finished with value: 0.7952580000000218 and parameters: {'min_samples_leaf': 900, 'max_depth': 20}. Best is trial 0 with value: 0.7952580000000218.
# [I 2023-01-28 11:51:32,823] Trial 7 finished with value: 0.3619260000000235 and parameters: {'min_samples_leaf': 800, 'max_depth': 10}. Best is trial 0 with value: 0.7952580000000218.
# [I 2023-01-28 11:51:32,969] Trial 2 finished with value: 0.3619260000000235 and parameters: {'min_samples_leaf': 700, 'max_depth': 25}. Best is trial 0 with value: 0.7952580000000218.
# [I 2023-01-28 11:51:33,019] Trial 5 finished with value: 0.3619260000000235 and parameters: {'min_samples_leaf': 600, 'max_depth': 20}. Best is trial 0 with value: 0.7952580000000218.
# [I 2023-01-28 11:51:33,043] Trial 1 finished with value: 0.3619260000000235 and parameters: {'min_samples_leaf': 600, 'max_depth': 15}. Best is trial 0 with value: 0.7952580000000218.
# [I 2023-01-28 11:51:33,196] Trial 3 finished with value: 2.2530960000000224 and parameters: {'min_samples_leaf': 400, 'max_depth': 15}. Best is trial 3 with value: 2.2530960000000224.
# [I 2023-01-28 11:51:34,177] Trial 9 finished with value: 0.3619260000000235 and parameters: {'min_samples_leaf': 700, 'max_depth': 5}. Best is trial 3 with value: 2.2530960000000224.
# [I 2023-01-28 11:51:34,651] Trial 8 finished with value: 4.020640000000023 and parameters: {'min_samples_leaf': 300, 'max_depth': 15}. Best is trial 8 with value: 4.020640000000023.
# [I 2023-01-28 11:51:34,817] Trial 4 finished with value: -9.088705999999991 and parameters: {'min_samples_leaf': 100, 'max_depth': 20}. Best is trial 8 with value: 4.020640000000023.
# [I 2023-01-28 11:51:34,905] Trial 11 finished with value: 0.3619260000000235 and parameters: {'min_samples_leaf': 800, 'max_depth': 15}. Best is trial 8 with value: 4.020640000000023.
# [I 2023-01-28 11:51:35,041] Trial 6 finished with value: -9.088705999999991 and parameters: {'min_samples_leaf': 100, 'max_depth': 25}. Best is trial 8 with value: 4.020640000000023.
# [I 2023-01-28 11:51:35,193] Trial 10 finished with value: 0.3619260000000235 and parameters: {'min_samples_leaf': 500, 'max_depth': 15}. Best is trial 8 with value: 4.020640000000023.
# [I 2023-01-28 11:51:35,376] Trial 13 finished with value: 2.2530960000000224 and parameters: {'min_samples_leaf': 400, 'max_depth': 15}. Best is trial 8 with value: 4.020640000000023.
# [I 2023-01-28 11:51:35,932] Trial 14 finished with value: 0.3619260000000235 and parameters: {'min_samples_leaf': 800, 'max_depth': 25}. Best is trial 8 with value: 4.020640000000023.
# [I 2023-01-28 11:51:36,089] Trial 17 finished with value: -26.053565999999996 and parameters: {'min_samples_leaf': 1100, 'max_depth': 5}. Best is trial 8 with value: 4.020640000000023.
# [I 2023-01-28 11:51:36,504] Trial 12 finished with value: -2.4917439999999758 and parameters: {'min_samples_leaf': 200, 'max_depth': 15}. Best is trial 8 with value: 4.020640000000023.
# CPU times: total: 3min 4s
# Wall time: 34.3 s

# %%
study.best_params
# Out:
# {'min_samples_leaf': 300, 'max_depth': 15}

# %% [markdown]
# ## Instantiating the classifier with hyper-parameters

# %%
t_clf = DecisionTreeClassifier(**study.best_params,random_state=123)

# %% [markdown]
# ## Now we can fit the tree with the training data

# %%
t_clf.fit(train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=15, min_samples_leaf=300, random_state=123)

# %% [markdown]
# ### and see how well it fits the training data

# %%
t_clf.score(train,y_train)
# Out:
# 0.5901578801588034

# %% [markdown]
# ### and predicts the validation data

# %%
t_clf.score(valid,y_valid)
# Out:
# 0.5844155844155844

# %% [markdown]
# ### The predicted labels on the validation set and their counts

# %%
pred_valid = t_clf.predict(valid)

# %%
Counter(pred_valid)
# Out:
# Counter({1: 1055, -1: 100})

# %%
confusion_matrix(pred_valid,y_valid)
# Out:
# array([[ 68,   8,  24],
#        [  0,   0,   0],
#        [335, 113, 607]], dtype=int64)

# %% [markdown]
# ### Visualizing the tree

# %%
dot_data = tree.export_graphviz(t_clf,out_file=None)
graph = graphviz.Source(dot_data)
graph.render('tree_11')
# Out:
# 'tree_11.pdf'

# %% [markdown]
# ## Now we are going to cut the features by looking at their importance in the tree. The visualization of the tree shows that only a few of the features are actually used

# %%
def tree_feat_importance(m, df):
    return pd.DataFrame({'cols':df.columns, 'feat_imp':m.feature_importances_}
                       ).sort_values('feat_imp', ascending=False)

def plot_fi(fi): return fi.plot('cols', 'feat_imp', 'barh', figsize=(12,7), legend=False)

# %%
fi = tree_feat_importance(t_clf,train)

# %%
fi
# Out:
#                   cols  feat_imp
# 40              oiadpq  0.178420
# 156          fcf_yield  0.117873
# 92          market_cap  0.074509
# 102           oancfy_q  0.072850
# 116               cfmq  0.052747
# ..                 ...       ...
# 258           sic_2780  0.000000
# 259           sic_2790  0.000000
# 260           sic_2800  0.000000
# 261           sic_2810  0.000000
# 720  sector_code_850.0  0.000000
#
# [721 rows x 2 columns]

# %% [markdown]
# ## We are only going to use the features that have positive feature importance i.e. occur in the tree

# %%
features = fi[(fi['feat_imp'] > 0.00)]

# %%
features
# Out:
#                  cols  feat_imp
# 40             oiadpq  0.178420
# 156         fcf_yield  0.117873
# 92         market_cap  0.074509
# 102          oancfy_q  0.072850
# 116              cfmq  0.052747
# 91   book_value_yield  0.052282
# 112              gpmq  0.041160
# 535          sic_6798  0.037105
# 78             oibdpy  0.033465
# 65              cdvcy  0.031487
# 39             oepsxq  0.031173
# 68             dlcchy  0.026671
# 168  cash_conversionq  0.023446
# 33               mibq  0.023021
# 127         lagicapt4  0.022336
# 80              txpdy  0.021198
# 121              ceq4  0.021169
# 62               xrdq  0.020759
# 101               psq  0.020512
# 45             ppentq  0.020103
# 158         lt_ppentq  0.019927
# 95               evmq  0.016305
# 6              csh12q  0.015828
# 145         rect_actq  0.014965
# 151       profit_lctq  0.010687

# %% [markdown]
# ### Feature importance spectrum

# %%
plot_fi(features);

# %% [markdown]
# #### We are left with a much smaller set of features

# %%
cols = features['cols'].values

# %%
len(cols)
# Out:
# 25

# %%
cols
# Out:
# array(['oiadpq', 'fcf_yield', 'market_cap', 'oancfy_q', 'cfmq',
#        'book_value_yield', 'gpmq', 'sic_6798', 'oibdpy', 'cdvcy',
#        'oepsxq', 'dlcchy', 'cash_conversionq', 'mibq', 'lagicapt4',
#        'txpdy', 'ceq4', 'xrdq', 'psq', 'ppentq', 'lt_ppentq', 'evmq',
#        'csh12q', 'rect_actq', 'profit_lctq'], dtype=object)

# %% [markdown]
# ### We cut down the training and validation data sets to only include the relevant features and retrain the tree on the reduced data set

# %%
train_red = pd.DataFrame(data = scaler.fit_transform(train[cols].values),columns = cols)
valid_red = pd.DataFrame(data = scaler.transform(valid[cols].values),columns = cols)
test_red = pd.DataFrame(data = scaler.transform(test[cols].values),columns = cols)

# %%
t_clf.fit(train_red,y_train)
# Out:
# DecisionTreeClassifier(max_depth=15, min_samples_leaf=300, random_state=123)

# %%
t_clf.score(train_red,y_train)
# Out:
# 0.5901578801588034

# %%
t_clf.score(valid_red,y_valid)
# Out:
# 0.5844155844155844

# %%
t_clf.feature_names_in_
# Out:
# array(['oiadpq', 'fcf_yield', 'market_cap', 'oancfy_q', 'cfmq',
#        'book_value_yield', 'gpmq', 'sic_6798', 'oibdpy', 'cdvcy',
#        'oepsxq', 'dlcchy', 'cash_conversionq', 'mibq', 'lagicapt4',
#        'txpdy', 'ceq4', 'xrdq', 'psq', 'ppentq', 'lt_ppentq', 'evmq',
#        'csh12q', 'rect_actq', 'profit_lctq'], dtype=object)

# %%
pred_valid = t_clf.predict(valid_red)

# %%
Counter(y_valid)
# Out:
# Counter({1: 631, -1: 403, 0: 121})

# %%
Counter(pred_valid)
# Out:
# Counter({1: 1055, -1: 100})

# %%
confusion_matrix(y_valid,pred_valid)
# Out:
# array([[ 68,   0, 335],
#        [  8,   0, 113],
#        [ 24,   0, 607]], dtype=int64)

# %%
profit = (pred_valid * df_valid['next_period_return'].values).sum()

# %%
profit
# Out:
# 4.020640000000023

# %%
valid_1 = valid_red.copy()

valid_1['rets'] = df_valid['next_period_return'].values

# %%
len(valid_1.columns)
# Out:
# 26

# %%
train_1 = train_red.copy()

train_1['rets'] = df_train['next_period_return'].values

# %%
len(train_1.columns)
# Out:
# 26

# %%
pred = t_clf.predict(valid_red)

# %%
(pred*valid_1[valid_1.columns[-1]].values).sum()
# Out:
# 4.020640000000023

# %%
# !pip install shap

# %%
import shap

# %%
def model(features):
    tree_features = features[features.columns[:-1].values]

    pred = t_clf.predict(tree_features)

    ret = pred * features[features.columns[-1]]

    return ret

# %%
explainer = shap.explainers.Permutation(model,valid_1)

# %%
shap_values = explainer(valid_1,max_evals=2000,)
# Out:
# Permutation explainer: 1156it [04:14,  4.43it/s]

# %%
shap_values.values.shape
# Out:
# (1155, 26)

# %%
shap.plots.bar(shap_values[:,:-1],max_display=30)

# %%
shap_cols = ['oiadpq','psq','fcf_yield','market_cap','gpmq','book_value_yield','oepsxq']
#operation income after depreciation-diluted, yearly sales,free cash flow yield,market cap,gross profit margin,book value yield,
#operating earnings per share-diluted

# %%
len(shap_cols)
# Out:
# 7

# %%
len(valid_1.columns[:-1])
# Out:
# 25

# %%
shap.summary_plot(shap_values[:,:-1], features=valid_1[valid_1.columns[:-1]],max_display=10)

# %%
len(shap_values[:,'fcf_yield'].values[shap_values[:,'fcf_yield'].values>0])
# Out:
# 151

# %%
shap.summary_plot(shap_values[:,:-1], features=list(valid_1.columns), class_inds=[2], max_display=10)

# %%
shap.plots.waterfall(shap_values[1000,:-1],max_display=10)

# %%
shap.plots.scatter(shap_values[:,'fcf_yield'], color=shap_values,xmax=2,xmin=-2,ymin=-0.05,ymax=0.05)

# %%
train_red.columns

# %%
sample_ind = 1000
shap.partial_dependence_plot(
    'market_cap', model, valid_1, model_expected_value=True,
    feature_expected_value=True, ice=True,
    shap_values=shap_values[sample_ind:sample_ind+1,:],xmax=2,xmin=-2)

# %%
clustering = shap.utils.hclust(test_1[test_1.columns[:-1]], y_test) # by default this trains (X.shape[1] choose 2) 2-feature XGBoost models
shap.plots.bar(shap_values[:,:-1], clustering=clustering)

# %%
shap.initjs()
shap.plots.force(shap_values[1000,:-1])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iYM0ETFNBCU0SK1PGGIWV'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.04890667000000006, "outValue": 0.06478200265625009, "link": "identity", "featureNames": ["oiadpq", "fcf_yield", "market_cap", "oancfy_q", "cfmq", "book_value_yield", "gpmq", "sic_6798", "oibdpy", "oepsxq", "dlcchy", "mibq", "lagicapt4", "psq"], "features": {"0": {"effect": 0.007412048125000004, "value": -0.2419798735287586}, "1": {"effect": 0.009139440000000009, "value": 0.13302612266059027}, "2": {"effect": -0.003185058125, "value": -0.30787939315525564}, "6": {"effect": -0.0031850581250000014, "value": 0.12271427924554472}, "9": {"effect": 0.0008539024999999986, "value": 0.01743789323673436}, "13": {"effect": 0.0048400582812500115, "value": -0.2917527716967493}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iYM0ETFNBCU0SK1PGGIWV')
#   );
# </script>

# %%
shap.force_plot( shap_values[:,:-1], valid_1[valid_1.columns[:-1]])
# Out:
# <div id='iTZHVQJD9N91Y51BVVSQD'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": -0.005816780000000022, "link": "identity", "featureNames": ["oiadpq", "fcf_yield", "market_cap", "oancfy_q", "cfmq", "book_value_yield", "gpmq", "sic_6798", "oibdpy", "cdvcy", "oepsxq", "dlcchy", "cash_conversionq", "mibq", "lagicapt4", "txpdy", "ceq4", "xrdq", "psq", "ppentq", "lt_ppentq", "evmq", "csh12q", "rect_actq", "profit_lctq"], "explanations": [{"outValue": -0.013997843243243244, "simIndex": 858.0, "features": {"0": {"effect": -0.0022650502702702626, "value": -0.2341839177012248}, "1": {"effect": -0.0023068062162162084, "value": 0.07191589341202399}, "2": {"effect": -0.00040734081081081043, "value": -0.24440868290347242}, "3": {"effect": 0.0, "value": -0.1720423630353962}, "4": {"effect": 0.0, "value": 0.019948108437973986}, "5": {"effect": 0.0, "value": -0.7107923056117913}, "6": {"effect": -0.0009258348648648645, "value": 0.016419715072686494}, "7": {"effect": 0.0, "value": -0.2193026934992825}, "8": {"effect": 0.0, "value": -0.2906332751067062}, "9": {"effect": 0.0, "value": -0.7593458271028738}, "10": {"effect": 1.5210000000000486e-05, "value": -0.17509798659494888}, "11": {"effect": 0.0, "value": 0.06478260255181902}, "12": {"effect": 0.0, "value": 0.1884818632450974}, "13": {"effect": 0.0, "value": -0.15917010950281918}, "14": {"effect": 0.0, "value": -0.2717849224953701}, "15": {"effect": 0.0, "value": -0.253002665089696}, "16": {"effect": 0.0, "value": -0.3470733041233396}, "17": {"effect": 0.0, "value": -0.11507171484634746}, "18": {"effect": -0.002291241081081076, "value": -0.2837155070072012}, "19": {"effect": 0.0, "value": -0.36716762882844645}, "20": {"effect": 0.0, "value": -0.13175802184441837}, "21": {"effect": 0.0, "value": 0.020230410415713208}, "22": {"effect": 0.0, "value": -0.11589718827124455}, "23": {"effect": 0.0, "value": -0.5412063960435564}, "24": {"effect": 0.0, "value": -0.22687697809144874}}}, {"outValue": -0.017909355405405468, "simIndex": 271.0, "features": {"0": {"effect": -0.003649974324324325, "value": -0.03229140430175879}, "1": {"effect": -0.00023296054054054073, "value": -0.010365936491909531}, "2": {"effect": 0.0070537962162162396, "value": 0.043084107648425726}, "3": {"effect": 0.0, "value": -0.03528959148953408}, "4": {"effect": 0.0, "value": 0.025645365275975822}, "5": {"effect": 5.014108108108273e-05, "value": -0.8319165891520071}, "6": {"effect": -0.009790863513513577, "value": 0.0713602998451691}, "7": {"effect": 0.0, "value": -0.2193026934992825}, "8": {"effect": 0.0, "value": -0.0517963873023524}, "9": {"effect": 0.0, "value": -0.7593458271028738}, "10": {"effect": -0.0009390929729729745, "value": 0.06994767864537525}, "11": {"effect": 0.0, "value": 0.06478260255181902}, "12": {"effect": 0.0, "value": 0.21165126399423365}, "13": {"effect": 0.0, "value": -0.15917010950281918}, "14": {"effect": 0.0, "value": -0.18069940025301442}, "15": {"effect": 0.0, "value": 0.22716795998279762}, "16": {"effect": 0.0, "value": -0.20856542147467239}, "17": {"effect": 0.0, "value": -0.2600684833663745}, "18": {"effect": -0.00458362135135135, "value": -0.14438749596407544}, "19": {"effect": 0.0, "value": -0.31189878808024474}, "20": {"effect": 0.0, "value": -0.1533286414380341}, "21": {"effect": 0.0, "value": 0.021857603871165254}, "22": {"effect": 0.0, "value": -0.04653855402118046}, "23": {"effect": 0.0, "value": -1.412097834053818}, "24": {"effect": 0.0, "value": 0.14179786995643767}}}, {"outValue": -0.014521405135135109, "simIndex": 199.0, "features": {"0": {"effect": -0.0018041756756756722, "value": 0.5766001061356224}, "1": {"effect": -0.003421397837837828, "value": 0.06637790756808801}, "2": {"effect": 0.004845088648648641, "value": 0.21277398694222832}, "3": {"effect": 0.0, "value": 0.5831311359329091}, "4": {"effect": 0.0, "value": 0.012744140415241101}, "5": {"effect": 0.0, "value": -0.8319165891520071}, "6": {"effect": -0.005068071891891857, "value": -0.002236414736631339}, "7": {" ...

# %%
shap.plots.heatmap(shap_values[:,:-1])

# %%
shap.plots.bar(shap_values[1000,:-1])

# %% [markdown]
# ## How well does it do on the test set?

# %%
t_clf1 = DecisionTreeClassifier(**study.best_params,random_state=123)

# %%
t_clf1.fit(train[shap_cols],y_train)
# Out:
# DecisionTreeClassifier(max_depth=15, min_samples_leaf=300, random_state=123)

# %%
test_set = test_red[shap_cols]
pred_test = t_clf1.predict(test_set)
# pred_test_avr = pred_test_avr/np.abs(pred_test_avr).sum()
(pred_test * df_test['next_period_return']).sum()
# Out:
# 80.444251

# %%
dot_data = tree.export_graphviz(t_clf1,out_file=None)
graph = graphviz.Source(dot_data)
graph.render('tree_12')
# Out:
# 'tree_12.pdf'

# %%
t_clf1.feature_names_in_
# Out:
# array(['oiadpq', 'psq', 'fcf_yield', 'market_cap', 'gpmq',
#        'book_value_yield', 'oepsxq'], dtype=object)

# %% [markdown]
# ## If we were 100% correct on the test set we would get this profit

# %%
(y_test * df_test['pred_rel_return']).sum()
# Out:
# 110.136907

# %% [markdown]
# ## A totally random strategy where we randomly decide whether to buy or sell

# %%
m = len(df_test['next_period_return'])

# %%
random_predictions = []
for _ in range(1000):
    pred_random = np.random.choice([-1,0,1],m)
    random_predictions.append((pred_random * df_test['next_period_return']).sum())

# %%
plt.hist(random_predictions,bins=30,density=True);

# %%
np.mean(random_predictions)
# Out:
# -0.13402440699999985

# %% [markdown]
# ## Now we run this strategy over the whole period and see how it performs

# %%
start_dates = [pd.to_datetime('2001-01-01') + pd.DateOffset(months = 3*i) for i in range(57)]
end_dates = [d + pd.DateOffset(months = 36) for d in start_dates]

# %%
training_frames = [data.loc[d:d+pd.DateOffset(months = 36)] for d in start_dates]
test_frames = [data.loc[d + pd.DateOffset(months=6):d+pd.DateOffset(months = 9)] for d in end_dates]

# %%
training_data = [d.reset_index() for d in training_frames]

# %%
test_data = [d.reset_index() for d in test_frames]

# %%
training_labels = [d['rel_performance'].values for d in training_frames]

# %%
scalers = [StandardScaler() for _ in range(len(training_data))]
           
opt_training_data = [pd.DataFrame(scalers[i].fit_transform(training_frames[i][shap_cols].values),columns=shap_cols) for i in range(len(training_data))]
opt_test_data = [pd.DataFrame(scalers[i].transform(test_frames[i][shap_cols].values),columns=shap_cols) for i in range(len(test_data))]

# %%
x = [1]
ret = []

for i in range(len(start_dates)-1):
        t_clf.fit(opt_training_data[i],training_labels[i])

        preds = t_clf.predict(opt_test_data[i])
        profit_i = (preds*test_frames[i]['next_period_return']).sum()
        ret.append(profit_i)
        num_names = len(opt_test_data[i])
        x.append(x[i] + (x[i]/num_names)*profit_i)

# %%
plt.plot(x);

# %%
len(x)
# Out:
# 57

# %%
plt.plot(ret)

# %% [markdown]
# ## Compared to a buy-and-hold of SPY

# %%
SPY = pd.read_pickle(r'C:\Users\niels\OneDrive\Machine Learning 2022\Lecture 2\SPY_cum_ret.pkl')
SPY = SPY.loc['2004-07-01':'2018-09-30']
SPY = SPY.resample('Q').ffill()
SPY['spy_cum_ret'] = (SPY['spy_cum_ret'] - SPY['spy_cum_ret'][0]+1)
SPY['strategy'] = x

# %%
SPY.plot();

# %%
SPY = SPY.resample('Y').ffill()

# %%
SPY.plot();

# %%
strategy_mean_ret = (SPY['strategy'] - 1).diff().mean()
strategy_std = (SPY['strategy'] - 1).diff().std()
print('Strategy Sharpe Ratio: ',strategy_mean_ret/strategy_std)
# Out:
# Strategy Sharpe Ratio:  0.8028787650424006

# %%
strategy_std
# Out:
# 0.1840246116346639

# %%
spy_mean_ret = (SPY['spy_cum_ret'] - 1).diff().mean()
spy_std = (SPY['spy_cum_ret'] - 1).diff().std()
print('SPY Sharpe Ratio: ',spy_mean_ret/spy_std)
# Out:
# SPY Sharpe Ratio:  0.6324646748042164

# %%
print(spy_std)
# Out:
# 0.1570446828772865

# %% [markdown]
# ### Total Returns

# %%
x[-1]
# Out:
# 3.1402665873498603

# %%
SPY['spy_cum_ret'][-1]
# Out:
# 2.4779340000000003

# %% [markdown]
# ### Computing the (quarterly) $\alpha$ of the strategy

# %%
strategy_ret = (SPY['strategy'] - 1).diff().values[1:]
spy_ret = (SPY['spy_cum_ret'] - 1).diff().values[1:]

# %%
beta = (np.cov(spy_ret,strategy_ret)/np.var(spy_ret))[1,0]
beta
# Out:
# 0.8756505565588316

# %%
residual_ret = strategy_ret - beta * spy_ret
IR = np.mean(residual_ret)/np.std(residual_ret)
IR
# Out:
# 0.2516397729728595

# %%
alpha = np.mean(residual_ret)
alpha
# Out:
# 0.020749863994616768
