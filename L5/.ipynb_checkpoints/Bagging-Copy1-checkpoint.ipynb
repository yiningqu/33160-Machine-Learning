# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
pd.set_option('use_inf_as_na', True)
from collections import Counter

# %%
raw_data = pd.read_pickle(r'C:\Users\niels\OneDrive\Machine Learning 2022\Lecture 2\dataset.pkl')

# %%
data = raw_data.drop([x  for x in raw_data.columns if 'fqtr' in x],axis=1)

# %%
data = raw_data[raw_data['market_cap'] > 1000.0]

# %%
data = data.copy()
data.fillna(0.0,inplace=True)

# %%
def f(x):
    if x > 0.05:
        return 1
    elif x < -0.1:
        return -1
    else:
    
        return 0

# %%
data['rel_performance'] = data['pred_rel_return'].apply(f)

# %%
data.reset_index(inplace=True,)
data.set_index('date',inplace=True)

data.sort_index()
data.head()

df_train = data.loc['2007-01-01':'2010-01-01']
df_valid = data.loc['2010-04-01':'2010-07-01']
df_test = data.loc['2010-07-01':'2010-10-01']

train = df_train.reset_index().drop(['ticker','date',
                                   'next_period_return',
                                   'spy_next_period_return',
                                   'rel_performance','pred_rel_return',
                                  'return', 'cum_ret', 'spy_cum_ret'],axis=1)


valid = df_valid.reset_index().drop(['ticker','date',
                                   'next_period_return',
                                   'spy_next_period_return',
                                   'rel_performance','pred_rel_return',
                                  'return', 'cum_ret', 'spy_cum_ret'],axis=1)
test = df_test.reset_index().drop(['ticker','date',
                                   'next_period_return',
                                   'spy_next_period_return',
                                   'rel_performance','pred_rel_return',
                                  'return', 'cum_ret', 'spy_cum_ret'],axis=1)

train_stock_returns = df_train['next_period_return']
valid_stock_returns = df_valid['next_period_return']
test_stock_returns = df_test['next_period_return']

y_train = df_train['rel_performance']
y_valid = df_valid['rel_performance']
y_test = df_test['rel_performance']

y_train = y_train.values
y_valid = y_valid.values
y_test = y_test.values

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
scaler = StandardScaler()

# %%
float_vars = [x for x in train.columns if data[x].dtype == 'float64']

# %%
len(float_vars)
# Out:
# 179

# %%
train_norm = train.copy()
valid_norm = valid.copy()
test_norm = test.copy()

# %%
train_norm[float_vars] = scaler.fit_transform(train[float_vars])
valid_norm[float_vars] = scaler.transform(valid[float_vars])
test_norm[float_vars] = scaler.transform(test[float_vars])

# %%
t_clf = DecisionTreeClassifier(max_depth=6,min_samples_leaf=200)

# %%
bg_clf = BaggingClassifier(t_clf,n_estimators=40,random_state=123,n_jobs=-1)

# %%
bg_clf.fit(train_norm,y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(max_depth=6,
#                                                    min_samples_leaf=200),
#                   n_estimators=40, n_jobs=-1, random_state=123)

# %%
def bagging_feat_importance(m, df):
    feature_importances = []
    for est in m.estimators_:
        fi = est.feature_importances_
        feature_importances.append(fi)
    feature_importances = np.array(feature_importances)
        
    return pd.DataFrame({'cols':train.columns, 'feat_imp':np.mean(feature_importances,axis=0)}
                       ).sort_values('feat_imp', ascending=False)


def plot_fi(fi): return fi.plot('cols', 'feat_imp', 'barh', figsize=(12,7), legend=False)

# %%
fi = bagging_feat_importance(bg_clf,train)

# %%
features = fi[(fi['feat_imp'] > 0.0)]
plot_fi(features);

# %%
len(features)
# Out:
# 165

# %%
bg_clf.score(train,y_train)
# Out:
# 0.40606361829025844

# %%
bg_clf.score(valid,y_valid)
# Out:
# 0.4073560027758501

# %%
pred_valid = bg_clf.predict(valid_norm)

# %%
Counter(pred_valid)
# Out:
# Counter({1: 849, 0: 587, -1: 5})

# %%
Counter(y_valid)
# Out:
# Counter({0: 618, 1: 546, -1: 277})

# %%
profit = (pred_valid*valid_stock_returns).sum()
profit
# Out:
# -33.34019700000003

# %%
import optuna
from optuna.trial import Trial

# %%
def objective(trial:Trial,train=None,labels=None,val=None,val_labels=None,val_rets=None):

    t_min_samples_leaf = trial.suggest_int('min_samples_leaf',100,1200,step=100)
    t_max_depth = trial.suggest_int('max_depth',5,25,step=5)
    t_n_estimators = trial.suggest_int('n_estimators',5,50,step=5)

    
    t_clf = DecisionTreeClassifier(min_samples_leaf = t_min_samples_leaf,max_depth=t_max_depth,random_state=123)
    bg_clf = BaggingClassifier(t_clf,n_estimators=t_n_estimators,random_state=123,n_jobs=1)
    bg_clf.fit(train,labels)

    preds = bg_clf.predict(val)
    profit = (preds * val_rets).sum()

#     score = bg_clf.score(val,val_labels)

    return profit

# %%
study = optuna.create_study(direction="maximize")
# Out:
# [I 2024-01-16 22:23:00,622] A new study created in memory with name: no-name-da3d506a-bcc3-435d-8367-70dc595e8922

# %%
from functools import partial

# %%
# %%time
study.optimize(partial(objective,train=train_norm,labels=y_train,val=valid_norm,val_labels=y_valid,val_rets=valid_stock_returns.values), n_trials=200,n_jobs=-1)
# Out:
# [I 2024-01-16 22:23:47,884] Trial 5 finished with value: -36.81940800000003 and parameters: {'min_samples_leaf': 1000, 'max_depth': 10, 'n_estimators': 20}. Best is trial 5 with value: -36.81940800000003.
# [I 2024-01-16 22:23:49,039] Trial 6 finished with value: -38.05767300000002 and parameters: {'min_samples_leaf': 1200, 'max_depth': 10, 'n_estimators': 25}. Best is trial 5 with value: -36.81940800000003.
# [I 2024-01-16 22:24:03,906] Trial 1 finished with value: -34.595847000000035 and parameters: {'min_samples_leaf': 300, 'max_depth': 15, 'n_estimators': 15}. Best is trial 1 with value: -34.595847000000035.
# [I 2024-01-16 22:24:30,834] Trial 2 finished with value: -33.19149500000004 and parameters: {'min_samples_leaf': 200, 'max_depth': 10, 'n_estimators': 20}. Best is trial 2 with value: -33.19149500000004.
# [I 2024-01-16 22:24:32,568] Trial 10 finished with value: -34.72863200000003 and parameters: {'min_samples_leaf': 600, 'max_depth': 25, 'n_estimators': 10}. Best is trial 2 with value: -33.19149500000004.
# [I 2024-01-16 22:24:47,989] Trial 9 finished with value: -38.14073200000004 and parameters: {'min_samples_leaf': 900, 'max_depth': 25, 'n_estimators': 25}. Best is trial 2 with value: -33.19149500000004.
# [I 2024-01-16 22:24:55,053] Trial 0 finished with value: -39.66087400000003 and parameters: {'min_samples_leaf': 900, 'max_depth': 15, 'n_estimators': 45}. Best is trial 2 with value: -33.19149500000004.
# [I 2024-01-16 22:25:00,306] Trial 7 finished with value: -27.672086000000057 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 20}. Best is trial 7 with value: -27.672086000000057.
# [I 2024-01-16 22:25:09,640] Trial 13 finished with value: -38.15846700000004 and parameters: {'min_samples_leaf': 1200, 'max_depth': 15, 'n_estimators': 10}. Best is trial 7 with value: -27.672086000000057.
# [I 2024-01-16 22:25:37,766] Trial 11 finished with value: -28.08749600000005 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 10}. Best is trial 7 with value: -27.672086000000057.
# [I 2024-01-16 22:25:41,599] Trial 4 finished with value: -38.11762600000003 and parameters: {'min_samples_leaf': 500, 'max_depth': 10, 'n_estimators': 45}. Best is trial 7 with value: -27.672086000000057.
# [I 2024-01-16 22:25:51,886] Trial 8 finished with value: -37.546071000000026 and parameters: {'min_samples_leaf': 700, 'max_depth': 5, 'n_estimators': 40}. Best is trial 7 with value: -27.672086000000057.
# [I 2024-01-16 22:26:18,740] Trial 18 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:26:30,899] Trial 19 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:26:32,328] Trial 3 finished with value: -35.054487000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 5, 'n_estimators': 50}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:26:55,412] Trial 22 finished with value: -33.63191400000004 and parameters: {'min_samples_leaf': 300, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:26:57,528] Trial 21 finished with value: -37.25211600000003 and parameters: {'min_samples_leaf': 400, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:27:09,237] Trial 15 finished with value: -37.94777200000004 and parameters: {'min_samples_leaf': 600, 'max_depth': 10, 'n_estimators': 40}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:27:44,192] Trial 16 finished with value: -37.32123000000002 and parameters: {'min_samples_leaf': 700, 'max_depth': 5, 'n_estimators': 50}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:28:06,843] Trial 17 finished with value: -38.53207900000003 and parameters: {'min_samples_leaf': 500, 'max_depth': 5, 'n_estimators': 40}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:29:08,819] Trial 14 finished with value: -32.25064200000004 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 40}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:29:14,415] Trial 20 finished with value: -38.62664100000003 and parameters: {'min_samples_leaf': 400, 'max_depth': 20, 'n_estimators': 35}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:29:19,155] Trial 23 finished with value: -38.62664100000003 and parameters: {'min_samples_leaf': 400, 'max_depth': 20, 'n_estimators': 35}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:29:19,388] Trial 12 finished with value: -33.14005200000003 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 45}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:29:29,519] Trial 25 finished with value: -37.65297300000004 and parameters: {'min_samples_leaf': 300, 'max_depth': 20, 'n_estimators': 30}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:30:21,440] Trial 24 finished with value: -37.60725500000003 and parameters: {'min_samples_leaf': 300, 'max_depth': 20, 'n_estimators': 35}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:30:26,124] Trial 27 finished with value: -37.65297300000004 and parameters: {'min_samples_leaf': 300, 'max_depth': 20, 'n_estimators': 30}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:30:33,549] Trial 26 finished with value: -37.60725500000003 and parameters: {'min_samples_leaf': 300, 'max_depth': 20, 'n_estimators': 35}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:31:01,265] Trial 30 finished with value: -29.648308000000068 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 15}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:31:13,484] Trial 28 finished with value: -29.648308000000068 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 15}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:31:14,143] Trial 32 finished with value: -29.648308000000068 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 15}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:31:19,297] Trial 29 finished with value: -29.648308000000068 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 15}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:31:21,636] Trial 31 finished with value: -29.648308000000068 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 15}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:31:38,651] Trial 36 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:31:44,063] Trial 37 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:32:06,639] Trial 41 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 15, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:32:08,923] Trial 38 finished with value: -30.631835000000034 and parameters: {'min_samples_leaf': 200, 'max_depth': 15, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:32:16,521] Trial 42 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 15, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:32:16,961] Trial 34 finished with value: -29.648308000000068 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 15}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:32:19,156] Trial 35 finished with value: -29.648308000000068 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 15}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:32:27,668] Trial 39 finished with value: -30.631835000000034 and parameters: {'min_samples_leaf': 200, 'max_depth': 15, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:32:29,257] Trial 33 finished with value: -29.648308000000068 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 15}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:32:29,569] Trial 40 finished with value: -30.631835000000034 and parameters: {'min_samples_leaf': 200, 'max_depth': 15, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:33:04,160] Trial 43 finished with value: -30.631835000000034 and parameters: {'min_samples_leaf': 200, 'max_depth': 15, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:33:16,525] Trial 46 finished with value: -36.540779000000036 and parameters: {'min_samples_leaf': 800, 'max_depth': 25, 'n_estimators': 20}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:33:18,617] Trial 47 finished with value: -36.540779000000036 and parameters: {'min_samples_leaf': 800, 'max_depth': 25, 'n_estimators': 20}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:33:19,134] Trial 45 finished with value: -38.103020000000036 and parameters: {'min_samples_leaf': 900, 'max_depth': 25, 'n_estimators': 20}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:33:33,498] Trial 54 finished with value: -38.27588400000003 and parameters: {'min_samples_leaf': 1100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:33:36,355] Trial 50 finished with value: -38.103020000000036 and parameters: {'min_samples_leaf': 900, 'max_depth': 20, 'n_estimators': 20}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:33:55,018] Trial 53 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:34:00,893] Trial 44 finished with value: -33.43316400000005 and parameters: {'min_samples_leaf': 200, 'max_depth': 15, 'n_estimators': 20}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:34:05,950] Trial 52 finished with value: -38.52192300000003 and parameters: {'min_samples_leaf': 1100, 'max_depth': 20, 'n_estimators': 20}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:34:16,567] Trial 57 finished with value: -37.25211600000003 and parameters: {'min_samples_leaf': 400, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:34:19,676] Trial 55 finished with value: -36.551668000000035 and parameters: {'min_samples_leaf': 500, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:34:22,670] Trial 56 finished with value: -36.551668000000035 and parameters: {'min_samples_leaf': 500, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:34:33,454] Trial 48 finished with value: -33.43316400000005 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 20}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:34:35,475] Trial 58 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:34:38,057] Trial 49 finished with value: -33.43316400000005 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 20}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:34:40,975] Trial 59 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:34:56,291] Trial 61 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:35:05,228] Trial 62 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:35:12,681] Trial 64 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:35:15,796] Trial 63 finished with value: -27.122508000000053 and parameters: {'min_samples_leaf': 100, 'max_depth': 10, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:35:18,082] Trial 66 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:35:19,572] Trial 67 finished with value: -33.63191400000004 and parameters: {'min_samples_leaf': 300, 'max_depth': 15, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:35:19,877] Trial 65 finished with value: -27.122508000000053 and parameters: {'min_samples_leaf': 100, 'max_depth': 10, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:35:22,033] Trial 51 finished with value: -27.672086000000057 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 20}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:35:32,129] Trial 60 finished with value: -28.08749600000005 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:35:44,562] Trial 70 finished with value: -33.63191400000004 and parameters: {'min_samples_leaf': 300, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:35:46,951] Trial 69 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:35:47,526] Trial 68 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:36:03,903] Trial 71 finished with value: -32.36191500000004 and parameters: {'min_samples_leaf': 300, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:36:08,281] Trial 74 finished with value: -32.36191500000004 and parameters: {'min_samples_leaf': 300, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:36:16,350] Trial 72 finished with value: -32.36191500000004 and parameters: {'min_samples_leaf': 300, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:36:17,030] Trial 73 finished with value: -32.36191500000004 and parameters: {'min_samples_leaf': 300, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:36:20,042] Trial 75 finished with value: -32.36191500000004 and parameters: {'min_samples_leaf': 300, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:36:34,841] Trial 77 finished with value: -32.36191500000004 and parameters: {'min_samples_leaf': 300, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:36:36,357] Trial 80 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:36:42,871] Trial 81 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:36:46,744] Trial 83 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 15, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:36:46,942] Trial 82 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:36:49,122] Trial 76 finished with value: -30.631835000000034 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:36:51,623] Trial 78 finished with value: -30.631835000000034 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:37:02,477] Trial 79 finished with value: -30.631835000000034 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:37:03,578] Trial 84 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:37:13,569] Trial 85 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:37:19,986] Trial 86 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:37:21,720] Trial 87 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:37:28,335] Trial 88 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:37:33,102] Trial 89 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:37:34,246] Trial 90 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:37:37,476] Trial 92 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:37:41,587] Trial 91 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:37:48,655] Trial 93 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 15, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:38:09,270] Trial 96 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 15, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:38:16,328] Trial 98 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:40:07,764] Trial 95 finished with value: -30.010962000000056 and parameters: {'min_samples_leaf': 100, 'max_depth': 15, 'n_estimators': 25}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:40:28,478] Trial 99 finished with value: -30.010962000000056 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 25}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:40:33,123] Trial 101 finished with value: -30.010962000000056 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 25}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:40:58,768] Trial 106 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:41:01,883] Trial 105 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:41:16,888] Trial 103 finished with value: -30.010962000000056 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 25}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:41:33,467] Trial 108 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:42:50,719] Trial 100 finished with value: -32.43309100000006 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 45}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:43:06,522] Trial 111 finished with value: -36.79733900000002 and parameters: {'min_samples_leaf': 600, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:43:16,925] Trial 97 finished with value: -32.43309100000006 and parameters: {'min_samples_leaf': 100, 'max_depth': 15, 'n_estimators': 45}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:43:31,568] Trial 102 finished with value: -32.43309100000006 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 45}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:43:46,354] Trial 94 finished with value: -31.983723000000065 and parameters: {'min_samples_leaf': 100, 'max_depth': 15, 'n_estimators': 50}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:43:55,829] Trial 110 finished with value: -37.46265000000004 and parameters: {'min_samples_leaf': 600, 'max_depth': 20, 'n_estimators': 45}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:44:02,044] Trial 112 finished with value: -30.631835000000034 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:44:18,630] Trial 113 finished with value: -30.631835000000034 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:44:28,261] Trial 114 finished with value: -30.631835000000034 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:44:30,460] Trial 115 finished with value: -33.199810000000035 and parameters: {'min_samples_leaf': 200, 'max_depth': 5, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:44:46,751] Trial 116 finished with value: -30.631835000000034 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:44:52,846] Trial 117 finished with value: -30.631835000000034 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:44:53,673] Trial 119 finished with value: -30.208636000000016 and parameters: {'min_samples_leaf': 100, 'max_depth': 5, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:44:54,260] Trial 118 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:45:03,871] Trial 120 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:45:20,597] Trial 121 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:45:24,776] Trial 122 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:45:34,999] Trial 104 finished with value: -31.983723000000065 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 50}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:45:35,122] Trial 124 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:45:35,423] Trial 123 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:45:39,800] Trial 125 finished with value: -27.122508000000053 and parameters: {'min_samples_leaf': 100, 'max_depth': 10, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:45:52,185] Trial 126 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:45:57,669] Trial 127 finished with value: -27.122508000000053 and parameters: {'min_samples_leaf': 100, 'max_depth': 10, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:46:06,469] Trial 128 finished with value: -27.122508000000053 and parameters: {'min_samples_leaf': 100, 'max_depth': 10, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:46:15,343] Trial 129 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:46:16,603] Trial 130 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:46:19,202] Trial 131 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:46:21,688] Trial 133 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:46:23,464] Trial 132 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:46:28,319] Trial 107 finished with value: -31.983723000000065 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 50}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:46:30,132] Trial 134 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:46:42,294] Trial 135 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:46:42,536] Trial 136 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:46:45,239] Trial 137 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:46:52,430] Trial 140 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:46:53,295] Trial 138 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:46:55,272] Trial 139 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:47:01,664] Trial 141 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:47:21,544] Trial 143 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:47:22,115] Trial 109 finished with value: -31.983723000000065 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 50}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:47:22,269] Trial 142 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:47:24,288] Trial 144 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:47:33,072] Trial 148 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:47:56,991] Trial 146 finished with value: -28.08749600000005 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:47:58,085] Trial 145 finished with value: -28.08749600000005 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:47:58,998] Trial 149 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:48:01,428] Trial 150 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:48:01,532] Trial 147 finished with value: -28.08749600000005 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:48:18,749] Trial 157 finished with value: -37.62985300000004 and parameters: {'min_samples_leaf': 700, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:48:28,816] Trial 155 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:48:29,126] Trial 154 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:48:33,371] Trial 158 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:48:33,582] Trial 156 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:48:33,884] Trial 152 finished with value: -28.08749600000005 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:48:34,635] Trial 151 finished with value: -28.08749600000005 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:48:37,158] Trial 153 finished with value: -28.08749600000005 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 10}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:48:52,570] Trial 159 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:49:00,791] Trial 160 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:49:01,856] Trial 166 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:49:05,765] Trial 161 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:49:08,689] Trial 162 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:49:13,724] Trial 169 finished with value: -37.62340000000003 and parameters: {'min_samples_leaf': 1000, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:49:23,139] Trial 167 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:49:33,221] Trial 168 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:49:40,508] Trial 171 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:49:45,601] Trial 172 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:49:47,406] Trial 165 finished with value: -38.34545100000003 and parameters: {'min_samples_leaf': 1200, 'max_depth': 20, 'n_estimators': 30}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:50:02,364] Trial 173 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:50:04,221] Trial 174 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:50:12,746] Trial 175 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:50:17,127] Trial 176 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:50:24,645] Trial 177 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:50:35,304] Trial 178 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:50:35,992] Trial 179 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:50:44,093] Trial 180 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:50:50,936] Trial 182 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:50:51,119] Trial 181 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:51:00,286] Trial 184 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:51:05,894] Trial 183 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:51:08,673] Trial 185 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:51:16,327] Trial 187 finished with value: -30.968513000000044 and parameters: {'min_samples_leaf': 200, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:51:27,232] Trial 164 finished with value: -31.816087000000042 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 30}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:51:28,186] Trial 163 finished with value: -31.816087000000042 and parameters: {'min_samples_leaf': 200, 'max_depth': 20, 'n_estimators': 30}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:51:31,208] Trial 186 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:51:32,052] Trial 188 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:51:41,254] Trial 190 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:51:43,243] Trial 189 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:51:48,313] Trial 192 finished with value: -37.25211600000003 and parameters: {'min_samples_leaf': 400, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:51:49,773] Trial 193 finished with value: -37.25211600000003 and parameters: {'min_samples_leaf': 400, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:51:50,550] Trial 191 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:52:06,535] Trial 195 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:52:06,681] Trial 194 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:52:13,273] Trial 170 finished with value: -30.02713900000007 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 30}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:52:15,421] Trial 197 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:52:17,616] Trial 198 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:52:18,535] Trial 199 finished with value: -26.801611000000044 and parameters: {'min_samples_leaf': 100, 'max_depth': 25, 'n_estimators': 5}. Best is trial 18 with value: -26.801611000000044.
# [I 2024-01-16 22:53:43,780] Trial 196 finished with value: -31.682513000000053 and parameters: {'min_samples_leaf': 100, 'max_depth': 20, 'n_estimators': 35}. Best is trial 18 with value: -26.801611000000044.
# CPU times: total: 3h 24min 34s
# Wall time: 30min 37s

# %%
study.best_params
# Out:
# {'min_samples_leaf': 500, 'max_depth': 15, 'n_estimators': 5}

# %%
t_cfl = DecisionTreeClassifier(**{'min_samples_leaf': 500, 'max_depth': 5})
bg_clf = BaggingClassifier(t_clf,n_estimators=5,random_state=123)

# %%
bg_clf.fit(train_norm,y_train)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(max_depth=6,
#                                                         min_samples_leaf=200),
#                   n_estimators=5, random_state=123)

# %%
pred_valid = bg_clf.predict(valid_norm)

# %%
bg_clf.score(train_norm,y_train)
# Out:
# 0.5923737420367464

# %%
bg_clf.score(valid_norm,y_valid)
# Out:
# 0.5645021645021645

# %%
confusion_matrix(pred_valid,y_valid)
# Out:
# array([[ 33,   2,   9],
#        [  0,   0,   0],
#        [369, 123, 619]], dtype=int64)

# %%
(pred_valid * df_valid['next_period_return'].values).sum()
# Out:
# -10.95675999999997

# %%
fi = bagging_feat_importance(bg_clf,train_norm)

# %%
features = fi[(fi['feat_imp'] > 0.0)]
plot_fi(features);

# %%
features
# Out:
#                 cols  feat_imp
# 156        fcf_yield  0.103983
# 40            oiadpq  0.072066
# 176         rd_saleq  0.054744
# 92        market_cap  0.046889
# 102         oancfy_q  0.046559
# ..               ...       ...
# 142     int_totdebtq  0.005082
# 59              txtq  0.004987
# 112             gpmq  0.004585
# 132  aftret_invcapxq  0.003935
# 15               dpq  0.003563
#
# [62 rows x 2 columns]

# %%
cols = features['cols'].values

# %%
cols
# Out:
# array(['fcf_yield', 'oiadpq', 'rd_saleq', 'market_cap', 'oancfy_q',
#        'oeps12', 'ibadj12', 'book_value_yield', 'oepf12', 'quick_ratioq',
#        'short_debtq', 'cf_yield', 'sic_6798', 'ibcy', 'xidoy', 'chechy',
#        'inv_turnq', 'ocf_lctq', 'dpcq', 'cfmq', 'oancfy', 'roeq',
#        'cfo-per-share', 'txpq', 'opmbdq', 'psq', 'dltisy', 'dltry',
#        'yearly_sales', 'xsgay', 'lagppent4', 'fcf_ocfq', 'cash_ratioq',
#        'de_ratioq', 'sale_equityq', 'evmq', 'opepsq', 'dvy', 'actq',
#        'capxq', 'ceq4', 'fcf_csfhdq', 'sale_invcapq', 'spiq', 'apq',
#        'dlttq', 'rect_actq', 'debt_assetsq', 'oepsxy', 'capeiq', 'nopiq',
#        'capxy', 'dprq', 'npmq', 'invt_actq', 'oibdpy', 'accrualq',
#        'int_totdebtq', 'txtq', 'gpmq', 'aftret_invcapxq', 'dpq'],
#       dtype=object)

# %%
float_vars = [x for x in train[cols].columns if data[x].dtype == 'float64']

# %%
len(float_vars)
# Out:
# 61

# %%
train_red_norm = train.copy()
valid_red_norm = valid.copy()
test_red_norm = test.copy()

# %%
(train[cols])[float_vars]
# Out:
#        fcf_yield    oiadpq  rd_saleq    market_cap   oancfy_q  oeps12  \
# 0      -0.018069    65.238  0.000000   3328.613563    -28.850  1.0300
# 1       0.066848   706.759  0.000000  17239.971000      0.000  2.0900
# 2       0.000000   119.606  0.000000   5006.277813      0.000  1.1000
# 3       0.032548  6880.430  0.000000  55073.831760  18080.311  0.0000
# 4       0.053088   401.000  0.000000  13470.818438    454.000  2.0400
# ...          ...       ...       ...           ...        ...     ...
# 10826  -0.018673   450.630  0.000000  10989.340000    918.053  4.2500
# 10827   0.096960   134.596  0.000000   3457.556200     19.060  1.9700
# 10828   0.038298    18.401  0.000000   1022.517050     14.156  1.1033
# 10829  -0.038154     0.600  0.156283   7924.391000    255.200 -1.4800
# 10830   0.003763    48.900  0.000000   5753.405700    -97.700  0.5700
#
#        ibadj12  book_value_yield  oepf12  quick_ratioq  ...      dprq  \
# 0      176.894          0.258732  1.0300      0.317598  ...  0.257194
# 1        0.000          0.875620  2.0900      0.000000  ...  0.000000
# 2      182.935          0.299951  1.1000      0.000000  ...  0.000000
# 3        0.000          0.000000  0.0000      0.000000  ...  0.000000
# 4        0.000          0.366496  2.0100      1.815374  ...  0.000000
# ...        ...               ...     ...           ...  ...       ...
# 10826    0.000          0.782038  4.2500      0.000000  ...  0.000000
# 10827  248.461          0.000000  1.9600      0.417276  ...  0.308515
# 10828   41.485          0.000000  1.0767      4.015399  ...  0.036350
# 10829 -961.900          0.660817 -1.4800      1.832117  ... -0.005926
# 10830    0.000          0.331484  0.5600      0.278610  ...  0.566032
#
#            npmq  invt_actq     oibdpy  accrualq  int_totdebtq     txtq  \
# 0      0.048261   0.830815     80.152   -22.188      0.000000   23.777
# 1      0.000000   0.000000      0.000     0.000      0.000000  500.314
# 2      0.000000   0.000000    556.662     0.000      0.000000   10.067
# 3      0.000000   0.000000  23218.970     0.000      0.000000  317.323
# 4      0.033685   0.061251    993.000  1188.000      0.085862  117.000
# ...         ...        ...        ...       ...           ...      ...
# 10826  0.000000   0.000000    695.292     0.000      0.000000   88.236
# 10827  0.012294   0.615851    664.843   408.879      0.079209   40.931
# 10828  0.106175   0.281997     58.473    20.592      0.000000    7.161
# 10829 -0.217111   0.191593    312.900  1395.900      0.033948   15.500
# 10830  0.212574   0.071429    499.300   -50.000      0.000000   22.800
#
#            gpmq  aftret_invcapxq      dpq
# 0      0.298141         0.294123   14.914
# 1      0.000000         0.000000    0.000
# 2      0.000000         0.000000   35.677
# 3      0.000000         0.000000  243.786
# 4      0.161122         0.000000  105.000
# ...         ...              ...      ...
# 10826  0.000000         0.000000  244.662
# 10827  0.150165         0.396773   68.564
# 10828  0.426688         0.000000    3.045
# 10829  0.335997        -0.146210  312.300
# 10830  0.325978         0.000000   39.000
#
# [10831 rows x 61 columns]

# %%
train_red_norm[float_vars] = scaler.fit_transform((train[cols])[float_vars])
valid_red_norm[float_vars] = scaler.transform((valid[cols])[float_vars])
test_red_norm[float_vars] = scaler.transform((test[cols])[float_vars])

# %%
bg_clf.fit(train[cols],y_train)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(max_depth=6,
#                                                         min_samples_leaf=200),
#                   n_estimators=5, random_state=123)

# %%
valid_1 = valid[cols].copy()

valid_1['rets'] = df_valid['next_period_return'].values

# %%
pred = bg_clf.predict(valid[cols])

# %%
(pred*valid_1[valid_1.columns[-1]].values).sum()
# Out:
# -10.95675999999997

# %%
import shap

# %%
def model(features):
    tree_features = features[features.columns[:-1].values]

    pred = bg_clf.predict(tree_features)

    ret = pred * features[features.columns[-1]]

    return ret

# %%
explainer = shap.explainers.Permutation(model,valid_1)

# %%
shap_values = explainer(valid_1,max_evals=2000,)
# Out:
# Permutation explainer: 1156it [12:39,  1.50it/s]

# %%
shap_values.values.shape
# Out:
# (1155, 63)

# %%
shap.plots.bar(shap_values[:,:-1],max_display=60,)

# %%
shap_cols = cols[np.abs(shap_values[:,:-1].values).mean(axis=0)>0.000]

# %%
shap_cols
# Out:
# array(['fcf_yield', 'oiadpq', 'rd_saleq', 'market_cap', 'oancfy_q',
#        'oeps12', 'ibadj12', 'book_value_yield', 'oepf12', 'quick_ratioq',
#        'short_debtq', 'cf_yield', 'sic_6798', 'ibcy', 'xidoy', 'chechy',
#        'inv_turnq', 'ocf_lctq', 'dpcq', 'cfmq', 'oancfy', 'roeq',
#        'cfo-per-share', 'txpq', 'opmbdq', 'psq', 'dltisy', 'dltry',
#        'yearly_sales', 'xsgay', 'lagppent4', 'fcf_ocfq', 'cash_ratioq',
#        'de_ratioq', 'sale_equityq', 'evmq', 'opepsq', 'dvy', 'actq',
#        'capxq', 'ceq4', 'fcf_csfhdq', 'sale_invcapq', 'apq', 'dlttq',
#        'rect_actq', 'capeiq', 'nopiq', 'capxy', 'npmq', 'invt_actq',
#        'oibdpy', 'accrualq', 'int_totdebtq', 'txtq', 'gpmq',
#        'aftret_invcapxq', 'dpq'], dtype=object)

# %%
len(shap_cols)
# Out:
# 58

# %%
shap.summary_plot(shap_values[:,:-1], features=valid_1[valid_1.columns[:-1]],max_display=30)

# %%
shap.plots.scatter(shap_values[:,'fcf_yield'], color=shap_values,xmax=2,xmin=-2,ymin=-0.05,ymax=0.05)

# %%
sample_ind = 1000
shap.partial_dependence_plot(
    'fcf_yield', model, valid_1, model_expected_value=True,
    feature_expected_value=True, ice=True,
    shap_values=shap_values[sample_ind:sample_ind+1,:],xmax=2,xmin=-2)

# %%
shap.initjs()
shap.plots.force(shap_values[800,:-1])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='i39PY11O1JN9NJ1USE6X0'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.006775670000000014, "outValue": -0.02554819066666665, "link": "identity", "featureNames": ["fcf_yield", "oiadpq", "rd_saleq", "market_cap", "oancfy_q", "oeps12", "ibadj12", "book_value_yield", "oepf12", "quick_ratioq", "short_debtq", "cf_yield", "sic_6798", "ibcy", "xidoy", "chechy", "inv_turnq", "ocf_lctq", "dpcq", "cfmq", "oancfy", "roeq", "cfo-per-share", "txpq", "opmbdq", "psq", "dltisy", "dltry", "yearly_sales", "xsgay", "lagppent4", "fcf_ocfq", "cash_ratioq", "de_ratioq", "sale_equityq", "evmq", "opepsq", "dvy", "actq", "capxq", "ceq4", "fcf_csfhdq", "sale_invcapq", "spiq", "apq", "dlttq", "rect_actq", "debt_assetsq", "oepsxy", "capeiq", "nopiq", "capxy", "dprq", "npmq", "invt_actq", "oibdpy", "accrualq", "int_totdebtq", "txtq", "gpmq", "aftret_invcapxq", "dpq"], "features": {"0": {"effect": -0.002954506666666654, "value": 0.3693460484821201}, "1": {"effect": -0.0035729886666666564, "value": 1139.587}, "2": {"effect": -0.0014670653333333354, "value": 0.0}, "3": {"effect": 0.0010156926666666658, "value": 4915.61455}, "4": {"effect": -0.00011359333333333226, "value": 1967.38}, "5": {"effect": -0.002601749333333333, "value": 1.19}, "7": {"effect": 0.0003500613333333335, "value": 0.0}, "8": {"effect": -0.00038564733333333254, "value": 1.18}, "9": {"effect": -0.0015677833333333333, "value": 0.0}, "10": {"effect": 0.00011359333333333226, "value": 0.002124805738254225}, "11": {"effect": -0.0012367693333333316, "value": 0.39840539424598065}, "15": {"effect": -0.0014002453333333334, "value": 561.915}, "25": {"effect": -0.0003500613333333333, "value": 3179.1099999999997}, "26": {"effect": -0.00011359333333333226, "value": 0.0}, "28": {"effect": -0.0005204513333333316, "value": 3179.1099999999997}, "29": {"effect": -0.0003500613333333333, "value": 163.748}, "30": {"effect": 0.000797260666666665, "value": 0.0}, "38": {"effect": -0.003067253333333326, "value": 0.0}, "39": {"effect": 0.00040609066666666584, "value": 143.499}, "49": {"effect": 0.0004052453333333317, "value": 0.57193926838102}, "50": {"effect": -0.00041937133333333346, "value": -697.695}, "58": {"effect": -0.0017393239999999967, "value": 40.968}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i39PY11O1JN9NJ1USE6X0')
#   );
# </script>

# %%
start_dates = [pd.to_datetime('2001-01-01') + pd.DateOffset(months = 3 * i) for i in range(57)]
end_dates = [d + pd.DateOffset(months = 36) for d in start_dates]

training_frames = [data.loc[d:d+pd.DateOffset(months = 36)] for d in start_dates]
valid_frames = [data.loc[d + pd.DateOffset(months=3):d+pd.DateOffset(months = 6)] for d in end_dates]
test_frames = [data.loc[d + pd.DateOffset(months=6):d+pd.DateOffset(months = 9)] for d in end_dates]

training_data = [d.reset_index().drop
                                 (['ticker','date',
                                   'next_period_return',
                                   'spy_next_period_return',
                                   'rel_performance','pred_rel_return',
                                  'return', 'cum_ret', 'spy_cum_ret'],axis=1) for d in training_frames]
valid_data = [d.reset_index().drop(['ticker','date',
                                   'next_period_return',
                                   'spy_next_period_return',
                                   'rel_performance','pred_rel_return',
                                  'return', 'cum_ret', 'spy_cum_ret'],axis=1) for d in valid_frames]
test_data = [d.reset_index().drop(['ticker','date',
                                   'next_period_return',
                                   'spy_next_period_return',
                                   'rel_performance','pred_rel_return',
                                  'return', 'cum_ret', 'spy_cum_ret'],axis=1) for d in test_frames]

training_labels = [d['rel_performance'].values for d in training_frames]
validation_labels = [d['rel_performance'].values for d in test_frames]

# %%
scalers = [StandardScaler() for _ in range(len(training_data))]
           
opt_training_data = [pd.DataFrame(scalers[i].fit_transform(training_frames[i][shap_cols].values),columns=shap_cols) for i in range(len(training_data))]
opt_valid_data = [pd.DataFrame(scalers[i].transform(valid_frames[i][shap_cols].values),columns=shap_cols) for i in range(len(valid_data))]
opt_test_data = [pd.DataFrame(scalers[i].transform(test_frames[i][shap_cols].values),columns=shap_cols) for i in range(len(test_data))]

# %%
x = [1]
ret = []

for i in range(len(start_dates)-1):
        t_clf.fit(opt_training_data[i],training_labels[i])

        preds = t_clf.predict(opt_test_data[i])
        profit_i = (preds*test_frames[i]['next_period_return']).sum()
        ret.append(profit_i)
        num_names = len(opt_test_data[i])
        x.append(x[i] + (x[i]/num_names)*profit_i)

# %%
plt.plot(x);

# %%
SPY = pd.read_pickle(r'C:\Users\niels\OneDrive\Machine Learning 2022\Lecture 2\SPY_cum_ret.pkl')
SPY = SPY.loc['2004-07-01':'2018-09-30']
SPY = SPY.resample('Q').ffill()
SPY['spy_cum_ret'] = (SPY['spy_cum_ret'] - SPY['spy_cum_ret'][0]+1)
SPY['strategy'] = x

# %%
SPY.plot();

# %%
SPY = SPY.resample('Y').ffill()

# %%
SPY.plot();

# %%
strategy_mean_ret = (SPY['strategy'] - 1).diff().mean()
strategy_std = (SPY['strategy'] - 1).diff().std()
strategy_sr = strategy_mean_ret/strategy_std
print('Strategy Sharpe Ratio: ',strategy_sr)
# Out:
# Strategy Sharpe Ratio:  0.807212507096343

# %%
strategy_std = (SPY['strategy'] - 1).diff().std()
strategy_std
# Out:
# 0.18177538113703628

# %%
(SPY['spy_cum_ret'] - 1).diff().mean()
(SPY['spy_cum_ret'] - 1).diff().std()
print('SP Sharpe Ratio: ',(SPY['spy_cum_ret'] - 1).diff().mean()/(SPY['spy_cum_ret'] - 1).diff().std())
# Out:
# SP Sharpe Ratio:  0.6324646748042164

# %%
x[-1]
# Out:
# 3.123298057609315

# %%
SPY['spy_cum_ret'][-1]
# Out:
# 2.4779340000000003

# %%
strategy_ret = (SPY['strategy'] - 1).diff().values[1:]
spy_ret = (SPY['spy_cum_ret'] - 1).diff().values[1:]

beta = (np.cov(spy_ret,strategy_ret)/np.var(spy_ret))[1,0]
beta
# Out:
# 1.2156955093767305

# %%
residual_ret = strategy_ret - beta * spy_ret
IR = np.mean(residual_ret)/np.std(residual_ret)
IR
# Out:
# 1.3622263859035815

# %%
alpha = np.mean(residual_ret)
alpha
# Out:
# 0.05288057431135689
